# %% [markdown]
# # Basic application
#
# This notebook shows you how to use the *basic* Vitis network example that can be generated from this repository.
# The design provides network connectivity using User Datagram Protocol (UDP) as the transport protocol.
#
# The assumptions made is this notebook are:
# 1. You have an Alveo card configured with one of the supported shells
# 1. You have generated the xclbin file for the *basic* example
# 1. You have a 100 GbE capable NIC
# 1. Both the Alveo card and the 100 GbE capable NIC are in the same host
# 1. Alveo card is connected to the NIC, either directly or with a any network equipment, using any of the interfaces.
#
# Let's have a look at the *basic* design.
#
# There are 4 Kernels:
# * CMAC: provides the translation between physical signals to AXI4-Stream interface
# * Network layer: provides a bridge between raw Ethernet packets and the application using UDP as transport layer
#     * ARP provides translation between MAC and IP addresses
#     * ICMP provides ping capabilities
#     * The UDP module has a 16-entry table with socket information that needs to be filled in before running
# * krnl_mm2s: reads data from memory and packetize it setting tdest and tlast appropriately
# * krnl_s2mm: read data from the stream and copy it to memory
#
# ![](../img/udp_network_basic.png)

# %% [markdown]
# In the followings cells we will:
# * Import the necessary pynq and python packages, define current device and xclbin file
# * Explore kernels in the design
# * Check physical link
# * Change Alveo card IP address and ping it
# * Configure socket table and populate it to the UDP module
# * Create UDP socket in the host
# * Allocate Alveo buffers
# * Move data from the HOST through the network (NIC) to the Alveo card
# * Move data from the HOST through the Alveo card to the network (NIC)
# * Free resources

# %% [markdown]
# ## Import packages and program FPGA
# In this section we need to import the `pynq` and python packages that will be used in the rest of this notebook. We also import the `vnx_utils.py` file with helper functions to set up the vnx examples.

# %%
import pynq
import numpy as np
from _thread import *
import threading 
import socket
from vnx_utils import *

# %% [markdown]
# We also need to define the current device, only if there is more than one Alveo card on the host. First let's check how many devices are available.

# %%
for i in range(len(pynq.Device.devices)):
    print("{}) {}".format(i, pynq.Device.devices[i].name))
# Out:
# 0) xilinx_u250_gen3x16_base_2
# 1) xilinx_u50_gen3x16_xdma_201920_3
# 2) xilinx_u280_xdma_201920_3

# %% [markdown]
# * If there are more than one Alveo card available, you should pass the `device` argument to the `pynq.Overlay` class.
# * The xclbin variable should point to the `xclbin` file for the *basic* example

# %%
currentDevice = pynq.Device.devices[2]
xclbin = '../basic.intf3.xilinx_u280_xdma_201920_3/vnx_basic_if3.xclbin'
ol = pynq.Overlay(xclbin,device=currentDevice)

# %% [markdown]
# ## Explore kernels in the design
# This design was built for both interfaces. Therefore, we will see each kernel repeated twice. One for the interface 0 and another for the interface 1

# %%
ol.ip_dict
# Out:
# {'cmac_0': {'phys_addr': 25165824,
#   'addr_range': 8192,
#   'type': 'xilinx.com:kernel:cmac_0:1.0',
#   'fullpath': 'cmac_0',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'led_status': {'address_offset': 128,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'gt_reset_reg': {'address_offset': 4096,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'reset_reg': {'address_offset': 4100,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'mode': {'address_offset': 4104,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'conf_tx': {'address_offset': 4108,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'conf_rx': {'address_offset': 4116,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'core_mode': {'address_offset': 4128,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'version': {'address_offset': 4132,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'gt_loopback': {'address_offset': 4240,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_status': {'address_offset': 4608,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_status': {'address_offset': 4612,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_status': {'address_offset': 4616,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_block_lock': {'address_offset': 4620,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_lane_sync': {'address_offset': 4624,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_lane_sync_err': {'address_offset': 4628,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_an_link_ctl': {'address_offset': 4704,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_lt_status': {'address_offset': 4708,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_pm_tick': {'address_offset': 4784,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_cycle_count': {'address_offset': 4792,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets': {'address_offset': 5376,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_good_packets': {'address_offset': 5384,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_bytes': {'address_offset': 5392,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_good_bytes': {'address_offset': 5400,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_64B': {'address_offset': 5408,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_65_127B': {'address_offset': 5416,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_128_255B': {'address_offset': 5424,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_256_511B': {'address_offset': 5432,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_512_1023B': {'address_offset': 5440,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1024_1518B': {'address_offset': 5448,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1519_1522B': {'address_offset': 5456,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1523_1548B': {'address_offset': 5464,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1549_2047B': {'address_offset': 5472,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_2048_4095B': {'address_offset': 5480,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_4096_8191B': {'address_offset': 5488,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_8192_9215B': {'address_offset': 5496,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_large': {'address_offset': 5504,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_small': {'address_offset': 5512,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_bad_fcs': {'address_offset': 5560,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_pause': {'address_offset': 5616,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_user_pause': {'address_offset': 5624,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets': {'address_offset': 5640,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_good_packets': {'address_offset': 5648,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_bytes': {'address_offset': 5656,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_good_bytes': {'address_offset': 5664,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_64B': {'address_offset': 5672,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_65_127B': {'address_offset': 5680,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_128_255B': {'address_offset': 5688,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_256_511B': {'address_offset': 5696,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_512_1023B': {'address_offset': 5704,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1024_1518B': {'address_offset': 5712,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1519_1522B': {'address_offset': 5720,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1523_1548B': {'address_offset': 5728,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1549_2047B': {'address_offset': 5736,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_2048_4095B': {'address_offset': 5744,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_4096_8191B': {'address_offset': 5752,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_8192_9215B': {'address_offset': 5760,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_large': {'address_offset': 5768,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_small': {'address_offset': 5776,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_undersize': {'address_offset': 5784,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_fragmented': {'address_offset': 5792,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_oversize': {'address_offset': 5800,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_toolong': {'address_offset': 5808,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_jabber': {'address_offset': 5816,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_bad_fcs': {'address_offset': 5824,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_packets_bad_fcs': {'address_offset': 5832,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_stomped_fcs': {'address_offset': 5840,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_pause': {'address_offset': 5880,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_user_pause': {'address_offset': 5888,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0}},
#   'streams': {'S_AXIS': {'id': 1,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'output',
#     'stream_id': 43},
#    'M_AXIS': {'id': 2,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'input',
#     'stream_id': 40}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 0,
#   'index': 0,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP},
#  'cmac_1': {'phys_addr': 25231360,
#   'addr_range': 8192,
#   'type': 'xilinx.com:kernel:cmac_1:1.0',
#   'fullpath': 'cmac_1',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'led_status': {'address_offset': 128,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'gt_reset_reg': {'address_offset': 4096,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'reset_reg': {'address_offset': 4100,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'mode': {'address_offset': 4104,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'conf_tx': {'address_offset': 4108,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'conf_rx': {'address_offset': 4116,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'core_mode': {'address_offset': 4128,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'version': {'address_offset': 4132,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'gt_loopback': {'address_offset': 4240,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_status': {'address_offset': 4608,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_status': {'address_offset': 4612,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_status': {'address_offset': 4616,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_block_lock': {'address_offset': 4620,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_lane_sync': {'address_offset': 4624,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_lane_sync_err': {'address_offset': 4628,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_an_link_ctl': {'address_offset': 4704,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_lt_status': {'address_offset': 4708,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_pm_tick': {'address_offset': 4784,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_cycle_count': {'address_offset': 4792,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets': {'address_offset': 5376,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_good_packets': {'address_offset': 5384,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_bytes': {'address_offset': 5392,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_good_bytes': {'address_offset': 5400,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_64B': {'address_offset': 5408,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_65_127B': {'address_offset': 5416,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_128_255B': {'address_offset': 5424,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_256_511B': {'address_offset': 5432,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_512_1023B': {'address_offset': 5440,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1024_1518B': {'address_offset': 5448,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1519_1522B': {'address_offset': 5456,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1523_1548B': {'address_offset': 5464,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_1549_2047B': {'address_offset': 5472,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_2048_4095B': {'address_offset': 5480,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_4096_8191B': {'address_offset': 5488,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_8192_9215B': {'address_offset': 5496,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_large': {'address_offset': 5504,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_packets_small': {'address_offset': 5512,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_total_bad_fcs': {'address_offset': 5560,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_pause': {'address_offset': 5616,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_tx_user_pause': {'address_offset': 5624,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets': {'address_offset': 5640,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_good_packets': {'address_offset': 5648,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_bytes': {'address_offset': 5656,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_good_bytes': {'address_offset': 5664,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_64B': {'address_offset': 5672,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_65_127B': {'address_offset': 5680,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_128_255B': {'address_offset': 5688,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_256_511B': {'address_offset': 5696,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_512_1023B': {'address_offset': 5704,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1024_1518B': {'address_offset': 5712,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1519_1522B': {'address_offset': 5720,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1523_1548B': {'address_offset': 5728,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_1549_2047B': {'address_offset': 5736,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_2048_4095B': {'address_offset': 5744,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_4096_8191B': {'address_offset': 5752,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_8192_9215B': {'address_offset': 5760,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_large': {'address_offset': 5768,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_small': {'address_offset': 5776,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_undersize': {'address_offset': 5784,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_fragmented': {'address_offset': 5792,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_oversize': {'address_offset': 5800,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_toolong': {'address_offset': 5808,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_packets_jabber': {'address_offset': 5816,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_total_bad_fcs': {'address_offset': 5824,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_packets_bad_fcs': {'address_offset': 5832,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_stomped_fcs': {'address_offset': 5840,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_pause': {'address_offset': 5880,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'stat_rx_user_pause': {'address_offset': 5888,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0}},
#   'streams': {'S_AXIS': {'id': 1,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'output',
#     'stream_id': 45},
#    'M_AXIS': {'id': 2,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'input',
#     'stream_id': 41}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 1,
#   'index': 1,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP},
#  'krnl_mm2s_0': {'phys_addr': 25296896,
#   'addr_range': 4096,
#   'type': 'xilinx.com:hls:krnl_mm2s:1.0',
#   'fullpath': 'krnl_mm2s_0',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'in_r': {'address_offset': 16,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'void*',
#     'id': 0,
#     'memory': 'HBM[0]'},
#    'size': {'address_offset': 28,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'unsigned int',
#     'id': 2},
#    'dest': {'address_offset': 36,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'unsigned int',
#     'id': 3}},
#   'streams': {'k2n': {'id': 1,
#     'type': 'stream<ap_axiu<512, 1, 1, 16>, 0>&',
#     'direction': 'output',
#     'stream_id': 46}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 2,
#   'index': 4,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP},
#  'krnl_mm2s_1': {'phys_addr': 25362432,
#   'addr_range': 4096,
#   'type': 'xilinx.com:hls:krnl_mm2s:1.0',
#   'fullpath': 'krnl_mm2s_1',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'in_r': {'address_offset': 16,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'void*',
#     'id': 0,
#     'memory': 'HBM[0]'},
#    'size': {'address_offset': 28,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'unsigned int',
#     'id': 2},
#    'dest': {'address_offset': 36,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'unsigned int',
#     'id': 3}},
#   'streams': {'k2n': {'id': 1,
#     'type': 'stream<ap_axiu<512, 1, 1, 16>, 0>&',
#     'direction': 'output',
#     'stream_id': 47}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 3,
#   'index': 5,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP},
#  'krnl_s2mm_0': {'phys_addr': 25427968,
#   'addr_range': 4096,
#   'type': 'xilinx.com:hls:krnl_s2mm:1.0',
#   'fullpath': 'krnl_s2mm_0',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'out_r': {'address_offset': 16,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'void*',
#     'id': 0,
#     'memory': 'HBM[0]'},
#    'size': {'address_offset': 28,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'unsigned int',
#     'id': 2}},
#   'streams': {'n2k': {'id': 1,
#     'type': 'stream<ap_axiu<512, 1, 1, 16>, 0>&',
#     'direction': 'input',
#     'stream_id': 42}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 4,
#   'index': 6,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP},
#  'krnl_s2mm_1': {'phys_addr': 25493504,
#   'addr_range': 4096,
#   'type': 'xilinx.com:hls:krnl_s2mm:1.0',
#   'fullpath': 'krnl_s2mm_1',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'out_r': {'address_offset': 16,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'void*',
#     'id': 0,
#     'memory': 'HBM[0]'},
#    'size': {'address_offset': 28,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'unsigned int',
#     'id': 2}},
#   'streams': {'n2k': {'id': 1,
#     'type': 'stream<ap_axiu<512, 1, 1, 16>, 0>&',
#     'direction': 'input',
#     'stream_id': 44}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 5,
#   'index': 7,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP},
#  'networklayer_0': {'phys_addr': 25559040,
#   'addr_range': 65536,
#   'type': 'xilinx.com:kernel:networklayer:1.0',
#   'fullpath': 'networklayer_0',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'mac_address': {'address_offset': 128,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ip_address': {'address_offset': 136,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'gateway': {'address_offset': 140,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ip_mask': {'address_offset': 144,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'constant_r': {'address_offset': 252,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_inbound_cycles': {'address_offset': 4096,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_inbound_bytes': {'address_offset': 4104,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_inbound_packets': {'address_offset': 4112,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'pkth_out_cycles': {'address_offset': 4120,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'pkth_out_bytes': {'address_offset': 4128,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'pkth_out_packets': {'address_offset': 4136,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_in_cycles': {'address_offset': 4144,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_in_bytes': {'address_offset': 4152,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_in_packets': {'address_offset': 4160,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_out_cycles': {'address_offset': 4168,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_out_bytes': {'address_offset': 4176,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_out_packets': {'address_offset': 4184,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_in_cycles': {'address_offset': 4192,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_in_bytes': {'address_offset': 4200,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_in_packets': {'address_offset': 4208,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_out_cycles': {'address_offset': 4216,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_out_bytes': {'address_offset': 4224,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_out_packets': {'address_offset': 4232,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ethhi_out_cycles': {'address_offset': 4240,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ethhi_out_bytes': {'address_offset': 4248,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ethhi_out_packets': {'address_offset': 4256,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_outbound_cycles': {'address_offset': 4264,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_outbound_bytes': {'address_offset': 4272,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_outbound_packets': {'address_offset': 4280,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_in_cycles': {'address_offset': 4288,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_in_bytes': {'address_offset': 4296,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_in_packets': {'address_offset': 4304,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_out_cycles': {'address_offset': 4312,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_out_bytes': {'address_offset': 4320,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_out_packets': {'address_offset': 4328,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_in_cycles': {'address_offset': 4336,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_in_bytes': {'address_offset': 4344,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_in_packets': {'address_offset': 4352,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_out_cycles': {'address_offset': 4360,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_out_bytes': {'address_offset': 4368,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_out_packets': {'address_offset': 4376,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_reset_counters': {'address_offset': 4592,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_clock_freq': {'address_offset': 4596,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_number_ports': {'address_offset': 4600,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_settings': {'address_offset': 4604,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_offset': {'address_offset': 8192,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_mac_addr_offset': {'address_offset': 18432,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_ip_addr_offset': {'address_offset': 20480,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_valid_offset': {'address_offset': 21504,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_discovery': {'address_offset': 21760,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0}},
#   'streams': {'S_AXIS_sk2nl': {'id': 1,
#     'type': 'stream<ap_axiu<512,0,0,16>>&',
#     'direction': 'output',
#     'stream_id': 46},
#    'M_AXIS_nl2sk': {'id': 3,
#     'type': 'stream<ap_axiu<512,0,0,16>>&',
#     'direction': 'input',
#     'stream_id': 42},
#    'S_AXIS_eth2nl': {'id': 2,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'output',
#     'stream_id': 40},
#    'M_AXIS_nl2eth': {'id': 4,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'input',
#     'stream_id': 43}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 6,
#   'index': 2,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP},
#  'networklayer_1': {'phys_addr': 25624576,
#   'addr_range': 65536,
#   'type': 'xilinx.com:kernel:networklayer:1.0',
#   'fullpath': 'networklayer_1',
#   'registers': {'CTRL': {'address_offset': 0,
#     'access': 'read-write',
#     'size': 4,
#     'description': 'OpenCL Control Register',
#     'type': 'unsigned int',
#     'id': None,
#     'fields': {'AP_START': {'access': 'read-write',
#       'bit_offset': 0,
#       'bit_width': 1,
#       'description': 'Start the accelerator'},
#      'AP_DONE': {'access': 'read-only',
#       'bit_offset': 1,
#       'bit_width': 1,
#       'description': 'Accelerator has finished - cleared on read'},
#      'AP_IDLE': {'access': 'read-only',
#       'bit_offset': 2,
#       'bit_width': 1,
#       'description': 'Accelerator is idle'},
#      'AP_READY': {'access': 'read-only',
#       'bit_offset': 3,
#       'bit_width': 1,
#       'description': 'Accelerator is ready to start next computation'},
#      'AUTO_RESTART': {'access': 'read-write',
#       'bit_offset': 7,
#       'bit_width': 1,
#       'description': 'Restart the accelerator automatically when finished'}}},
#    'mac_address': {'address_offset': 128,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ip_address': {'address_offset': 136,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'gateway': {'address_offset': 140,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ip_mask': {'address_offset': 144,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'constant_r': {'address_offset': 252,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_inbound_cycles': {'address_offset': 4096,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_inbound_bytes': {'address_offset': 4104,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_inbound_packets': {'address_offset': 4112,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'pkth_out_cycles': {'address_offset': 4120,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'pkth_out_bytes': {'address_offset': 4128,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'pkth_out_packets': {'address_offset': 4136,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_in_cycles': {'address_offset': 4144,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_in_bytes': {'address_offset': 4152,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_in_packets': {'address_offset': 4160,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_out_cycles': {'address_offset': 4168,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_out_bytes': {'address_offset': 4176,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_out_packets': {'address_offset': 4184,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_in_cycles': {'address_offset': 4192,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_in_bytes': {'address_offset': 4200,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_in_packets': {'address_offset': 4208,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_out_cycles': {'address_offset': 4216,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_out_bytes': {'address_offset': 4224,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'icmp_out_packets': {'address_offset': 4232,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ethhi_out_cycles': {'address_offset': 4240,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ethhi_out_bytes': {'address_offset': 4248,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'ethhi_out_packets': {'address_offset': 4256,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_outbound_cycles': {'address_offset': 4264,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_outbound_bytes': {'address_offset': 4272,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'eth_outbound_packets': {'address_offset': 4280,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_in_cycles': {'address_offset': 4288,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_in_bytes': {'address_offset': 4296,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_in_packets': {'address_offset': 4304,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_out_cycles': {'address_offset': 4312,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_out_bytes': {'address_offset': 4320,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_out_packets': {'address_offset': 4328,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_in_cycles': {'address_offset': 4336,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_in_bytes': {'address_offset': 4344,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_in_packets': {'address_offset': 4352,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_out_cycles': {'address_offset': 4360,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_out_bytes': {'address_offset': 4368,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_app_out_packets': {'address_offset': 4376,
#     'access': 'read-write;',
#     'size': 64,
#     'host_size': 8,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_reset_counters': {'address_offset': 4592,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_clock_freq': {'address_offset': 4596,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_number_ports': {'address_offset': 4600,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'debug_settings': {'address_offset': 4604,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'udp_offset': {'address_offset': 8192,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_mac_addr_offset': {'address_offset': 18432,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_ip_addr_offset': {'address_offset': 20480,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_valid_offset': {'address_offset': 21504,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0},
#    'arp_discovery': {'address_offset': 21760,
#     'access': 'read-write;',
#     'size': 32,
#     'host_size': 4,
#     'description': 'OpenCL Argument Register',
#     'type': 'uint',
#     'id': 0}},
#   'streams': {'S_AXIS_sk2nl': {'id': 1,
#     'type': 'stream<ap_axiu<512,0,0,16>>&',
#     'direction': 'output',
#     'stream_id': 47},
#    'M_AXIS_nl2sk': {'id': 3,
#     'type': 'stream<ap_axiu<512,0,0,16>>&',
#     'direction': 'input',
#     'stream_id': 44},
#    'S_AXIS_eth2nl': {'id': 2,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'output',
#     'stream_id': 41},
#    'M_AXIS_nl2eth': {'id': 4,
#     'type': 'stream<ap_axiu<512,0,0,0>>&',
#     'direction': 'input',
#     'stream_id': 45}},
#   'mem_id': None,
#   'state': None,
#   'interrupts': {},
#   'gpio': {},
#   'xclbin_uuid': '2cbf7f40ed974a979c6afbdf4225850c',
#   'adjusted_index': 7,
#   'index': 3,
#   'device': <pynq.pl_server.xrt_device.XrtDevice at 0x7f1f2726ac50>,
#   'driver': pynq.overlay.DefaultIP}}

# %% [markdown]
# ## Check physical link
# After the dynamic region of the Alveo card is programmed with the basic example we can start interacting with the design.
#
# Let's check if the Alveo card has detected link with the network equipment. To do so, we will use one of the helper functions `linkStatus`

# %%
print("Link interface 0 {}; link interface 1 {}".format(linkStatus(ol.cmac_0),linkStatus(ol.cmac_1)))
# Out:
# Link interface 0 {'cmac_link': True}; link interface 1 {'cmac_link': False}

# %% [markdown]
# ## Change Alveo card IP address and ping it
# By defaul the Alveo IP address is `192.168.0.5` and MAC address is `00:0A:35:02:9D:E5`. Let's change it to `197.11.27.12`, in this example we are using interface 0
#
# After the IP address is changed, we can ping the Alveo card. The first attempts will fail but the remaining should work.
#
# **Make sure you have configured the IP address of the 100 GbE capable NIC to be in the same subnetwork as the Alveo card**

# %%
alveo_ipaddr = '197.11.27.12'
updateIPAddress(ol.networklayer_0, alveo_ipaddr, True)
# Out:
# {'HWaddr': '00:0a:35:02:9d:0c',
#  'inet addr': '197.11.27.12',
#  'gateway addr': '192.168.0.1',
#  'Mask': '192.168.0.1'}

# %% [markdown]
# * Check 100 GbE capable NIC configuration

# %%
# !ifconfig enp115s0f1
# Out:
# enp115s0f1 Link encap:Ethernet  HWaddr a7:e5:2a:b9:01:c5
#           inet addr:197.11.27.55  Bcast:197.11.27.255  Mask:255.255.255.0
#           UP BROADCAST MULTICAST  MTU:1500  Metric:1
#           RX packets:0 errors:0 dropped:0 overruns:0 frame:0
#           TX packets:0 errors:0 dropped:0 overruns:0 carrier:0
#           collisions:0 txqueuelen:1000
#           RX bytes:352573447 (352.5 MB)  TX bytes:52137528 (52.1 MB)

# %% [markdown]
# * Run ping to get ARP set up
# Some of the attempts will fail but the remaining should work.

# %%
# !ping -c 5 197.11.27.12
# Out:
# PING 197.11.27.12 (197.11.27.12) 56(84) bytes of data.
# 64 bytes from 197.11.27.12: icmp_seq=3 ttl=128 time=0.111 ms
# 64 bytes from 197.11.27.12: icmp_seq=4 ttl=128 time=0.048 ms
# 64 bytes from 197.11.27.12: icmp_seq=5 ttl=128 time=0.037 ms
#
# --- 197.11.27.12 ping statistics ---
# 5 packets transmitted, 3 received, 40% packet loss, time 3999ms
# rtt min/avg/max/mdev = 0.037/0.065/0.111/0.033 ms

# %% [markdown]
# ## Configure socket table and populate it to the UDP module
#
# In this section we will define the socket table in software and populate it to the UDP module in the Alveo card.
# 1. We define `socketType` and initialize the 16 entries to zero
# 2. A couple of connections are created
# 3. The socket table is populated to the UDP module in the Alveo card using the `initSocketTable` helper function

# %%
socketType = np.dtype([('theirIP', np.uint32), ('theirPort', np.uint16), ('myPort', np.uint16), ('valid', np.bool)])
sockets = np.zeros(16, dtype=socketType)
sockets[0] = (0xC0A80019, 50446, 60133, True)
sockets[1] = (0xC0A80019, 38746, 62781, True)
initSocketTable(ol, sockets, interface = 0, device=currentDevice, debug=True)
# Out:
# Number of Sockets: 16
# HW socket table[  0], ti: 0xc0a80019	tp: 50446	mp: 60133	v: 1
# HW socket table[  1], ti: 0xc0a80019	tp: 38746	mp: 62781	v: 1
# HW socket table[  2], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[  3], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[  4], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[  5], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[  6], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[  7], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[  8], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[  9], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[ 10], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[ 11], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[ 12], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[ 13], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[ 14], ti: 0x00000000	tp:     0	mp:     0	v: 0
# HW socket table[ 15], ti: 0x00000000	tp:     0	mp:     0	v: 0

# %% [markdown]
# ## Create UDP socket in the host
# In this part we will open an UDP socket in the host (software) to be able to communicate with the Alveo card through the network.
#
# We will use the python socket API to do so, the socket will be binded to the port `38746`

# %%
SW_PORT = sockets[1]['theirPort']
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM) # UDP
sock.bind(('', SW_PORT))

# %% [markdown]
# ## Allocate Alveo buffers
#
# We need to allocate the buffers on the global memory of the Alveo card to be able to pull and push data from them. We also will initialize the the sending buffer, `mm2s_buf`, with random data. This random data will be sent later to the network.
#
# 1. Define alias for the application kernlels (`mm2s` and `s2mm`)
# 1. Define size and shape of the buffers
# 1. Allocate the buffers
# 1. Initialize sending buffer with random data

# %%
mm2s = ol.krnl_mm2s_0
s2mm = ol.krnl_s2mm_0

size = 1408 * 100
shape = (size,1)

mm2s_buf = pynq.allocate(shape, dtype=np.uint8, target=ol.HBM0)
s2mm_buf = pynq.allocate(shape, dtype=np.uint8, target=ol.HBM0)

mm2s_buf[:] = np.random.randint(low=0, high=((2**8)-1), size=shape, dtype=np.uint8)

# %% [markdown]
# ## Move data from the HOST through the network (NIC) to the Alveo card
#
# In this section we will write data to the socket, which will send such data from the host to the Alveo card using the network.
#
# Start streaming to memory mapped kernel, we need to specify how much data to expect from the network.

# %%
s2mm_wh = s2mm.start(s2mm_buf,size)

# %% [markdown]
# Initialize a buffer with random data, define the packet size and compute how many packets we need to send to transmit the whole buffer to the network. Write the data from the buffer into the socket in `BYTES_PER_PACKET` chunks.

# %%
udp_message_global = np.random.randint(low=0, high=((2**8)-1), size=shape, dtype=np.uint8)
BYTES_PER_PACKET = 1408
num_pkts = size//BYTES_PER_PACKET
alveo_port = sockets[1]['myPort']
for m in range(num_pkts):
    udp_message_local = udp_message_global[(m * BYTES_PER_PACKET) : ((m * BYTES_PER_PACKET) + BYTES_PER_PACKET)]
    sock.sendto(udp_message_local, (alveo_ipaddr, alveo_port))

# %% [markdown]
# * Wait for the s2mm kernel to receive all the data
# * Move data from global memory to HOST memory
# * Compare what was sent against what was received and print out result

# %%
s2mm_wh.wait()
s2mm_buf.sync_from_device()

msg = "SUCCESS!" if np.array_equal(udp_message_global, s2mm_buf) else "FAILURE!"
print("Host sending data through the network and the host getting data from kernel \
was a: {}. Total data transmitted {:,} bytes to {}" .format(msg,size,(alveo_ipaddr, alveo_port)))
# Out:
# Host sending data through the network and the host getting data from kernel was a: SUCCESS!. Total data transmitted 140,800 bytes to ('192.168.0.5', 62781)

# %% [markdown]
# ## Move data from the HOST through the Alveo card to the network (NIC)
#
# We need to create a new thread to read data from the socket, this mainly because there will be multiple packets. This is done in the `socket_receive_threaded` function

# %%
print_lock = threading.Lock() 
# thread function 
def socket_receive_threaded(sock, size): 
    BYTES_PER_PACKET = 1408
    shape_global = (size,1)
    shape_local = (BYTES_PER_PACKET,1)
    recv_data_global = np.empty(shape_global, dtype = np.uint8)
    data_partial = np.empty(shape_local, dtype = np.uint8)
    num_it = (size // BYTES_PER_PACKET)
    global mm2s_buf
    sum_bytes = 0
    connection = 'None'
    for m in range(num_it):
        res = sock.recvfrom_into(data_partial) 
        recv_data_global[(m * BYTES_PER_PACKET) : ((m * BYTES_PER_PACKET) + BYTES_PER_PACKET)] = data_partial
        sum_bytes = sum_bytes + int(res[0])
        connection = res[1]
    msg = "SUCCESS!" if np.array_equal(mm2s_buf, recv_data_global) else "FAILURE!"
    print ("Kernel sending data to the network and the host getting data from network \
    was a: {}. Total data received {:,} bytes from {}".format(msg,sum_bytes,connection))

# %% [markdown]
# * Copy random data to Alveo global memory
# * Acquire thread
# * Launch threaded function
# * Start kernel memory mapped to stream kernel, this will start sending UDP packets from the Alveo card to the NIC
# * Threaded function will start receiving data and it will print out result once ALL data was collected

# %%
mm2s_buf.sync_to_device()
print_lock.acquire() 
start_new_thread(socket_receive_threaded, (sock,size,))
mm2s_wh = mm2s.start(mm2s_buf,size, 1)
# Out:
# Kernel sending data to the network and the host getting data from network was a: SUCCESS!. Total data received 140,800 bytes from ('192.168.0.5', 62781)

# %% [markdown]
# ## Free resources
# Delete buffers and free Alveo card

# %%
del mm2s_buf
del s2mm_buf
del udp_message_global
pynq.Overlay.free(ol)

# %% [markdown]
# ------------------------------------------
# Copyright (c) 2020, Xilinx, Inc.
